# %% [markdown]
# <a href="https://colab.research.google.com/github/SHEHAN-120/R-statistics-precip/blob/main/precip_analysis_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The precip dataset in R provides annual precipitation levels (in inches) for 70 different U.S. cities. Use this dataset to perform the following analyses:
#
#
# a) Create a stem-and-leaf plot to visualize the distribution of precipitation levels. Describe any patterns or characteristics you observe in the data.
#
# b) Calculate the five-number summary and other key descriptive statistics for the dataset.
#
# c) Determine the sample standard deviation and variance of the precipitation measurements.
#
# d) Draw a boxplot to illustrate the spread and skewness of the data. Comment on the presence of any potential outliers.
#
# e) Produce a Q-Q (quantile-quantile) plot to assess whether the precipitation data follows a normal distribution. Interpret the results.
# #---

# %%
precip
# Out:
#              Mobile              Juneau             Phoenix         Little Rock
#                67.0                54.7                 7.0                48.5
#         Los Angeles          Sacramento       San Francisco              Denver
#                14.0                17.2                20.7                13.0
#            Hartford          Wilmington          Washington        Jacksonville
#                43.4                40.2                38.9                54.5
#               Miami             Atlanta            Honolulu               Boise
#                59.8                48.3                22.9                11.5
#             Chicago              Peoria        Indianapolis          Des Moines
#                34.4                35.1                38.7                30.8
#             Wichita          Louisville         New Orleans            Portland
#                30.6                43.1                56.8                40.8
# ...

# %%
x<-precip

# %%
x
# Out:
#              Mobile              Juneau             Phoenix         Little Rock
#                67.0                54.7                 7.0                48.5
#         Los Angeles          Sacramento       San Francisco              Denver
#                14.0                17.2                20.7                13.0
#            Hartford          Wilmington          Washington        Jacksonville
#                43.4                40.2                38.9                54.5
#               Miami             Atlanta            Honolulu               Boise
#                59.8                48.3                22.9                11.5
#             Chicago              Peoria        Indianapolis          Des Moines
#                34.4                35.1                38.7                30.8
#             Wichita          Louisville         New Orleans            Portland
#                30.6                43.1                56.8                40.8
# ...

# %%
stem(x)
# Out:
#   The decimal point is 1 digit(s) to the right of the |
#
#   0 | 7788
#   1 | 234555677
#   2 | 13569
#   3 | 001111233455666667789999
#   4 | 0001123333333566688999
#   5 | 5579
#   6 | 07

# %%
summary(x)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    7.00   29.38   36.60   34.89   42.77   67.00

# %%
sd(x)
# Out:
# [1] 13.70665

# %%
var(x)
# Out:
# [1] 187.8723

# %%
boxplot(
  x,
  main="Boxplot",
  ylab="Precip data",
  col="yellow"
)
# Out:
# Plot with title “Boxplot”

# %% [markdown]
# ### The boxplot have unusual datapoints (Outliers).

# %%
qqnorm(x,main="Q-Q plot",col="pink")
qqline(x,col="black")
# Out:
# Plot with title “Q-Q plot”

# %%
shapiro.test(x)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  x
# W = 0.96456, p-value = 0.04493

# %% [markdown]
# ### p_value is less than alpha value. so dataset is not normallity met.
